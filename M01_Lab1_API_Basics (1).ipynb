# %% [markdown]
# <!-- dads-lab-header -->
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mdehghani86/DADS5250-GenAI/blob/main/labs/M01/M01_Lab1_API_Basics.ipynb)
#
# ![M01 Lab1 API Basics](https://raw.githubusercontent.com/mdehghani86/DADS5250-GenAI/main/labs/M01/assets/images/M01_Lab1_API_Basics_banner.png)

# %% [markdown]
# ## 🚀 Before You Start: What the Setup Cell Does
#
# The first code cell (just below) gets your notebook ready. You run it **once** each time you open the lab. In plain English, it does three things:
#
# 1. **Installs the course toolkit, `dads5250`.** Rather than copy the same helper code into every lab, we bundled it into one small package on [PyPI](https://pypi.org/project/dads5250), which is Python's public library of packages. "Installing" simply means downloading it so your notebook can use it. The toolkit gives you shortcuts like `setup_openai()` to connect to OpenAI and `pp()` / `pretty_print()` to show results in tidy boxes.
# 2. **Makes sure the OpenAI SDK is present.** The SDK is the official Python library that lets your code talk to OpenAI's models.
# 3. **Imports those helpers** so you can call them by name for the rest of the lab.
#
# > ▶️ **Run the cell below now:** click it and press **Shift + Enter**. The first run can take about 20 seconds while it downloads. After that it is instant, and you never need to edit it.

# %%
# === Shared lab setup: install dads5250 + load API key + sticky pill ===
# Installs the shared utilities (pp, pretty_print, lab_pill, model constants,
# setup_openai, setup_gemini) once per Colab runtime. The same OPENAI_API_KEY
# / GEMINI_API_KEY Colab secrets are used across every DADS 5250 lab, set
# them once in the 🔑 sidebar and they're picked up automatically.
import os
# Course toolkit: the shared dads5250 helpers, installed from PyPI (pypi.org/project/dads5250).
# Pinned to ==0.2.0 so this notebook runs exactly as recorded. Bump the version here to upgrade.
import importlib.util
if importlib.util.find_spec("dads5250") is None:
    # !pip install -q dads5250==0.2.0

from dads5250 import (
    pp,
    pretty_print,
    lab_pill,
    setup_openai,
    setup_gemini,
    DEFAULT_CHAT_MODEL,  # newest reasoning model that supports temperature
    DEFAULT_MINI_MODEL,  # newest mini model that supports temperature
    DEFAULT_EMBED_MODEL, # current embeddings default
    DEFAULT_GEMINI_MODEL, # tracks the latest stable flash
)

lab_pill('M01 Lab 1, API Basics')            # sticky banner so you always see which lab you're in
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 62.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.2 MB/s eta 0:00:00
#     <div style="position: sticky; top: 0; z-index: 9999; text-align: center;
#                 padding: 6px 0; pointer-events: none;">
#       <span style="display: inline-block; background: #0055d4; color: white;
#                    padding: 6px 16px; border-radius: 999px;
#                    font-family: 'Segoe UI', sans-serif; font-size: 12px;
#                    font-weight: 600; letter-spacing: 0.5px;
#                    box-shadow: 0 2px 6px rgba(0,0,0,0.15);">
#         📘 M01 Lab 1, API Basics
#       </span>
#     </div>

# %% [markdown]
# ## ✅ API Check: Are We Connected?
#
# Before running any prompts, we confirm your key works. The cell below calls `setup_openai()`, which does three small things:
#
# - reads your `OPENAI_API_KEY` (from a Colab Secret, an environment variable, or a hidden prompt if neither is set),
# - makes one tiny test call to verify the key is valid, and
# - returns a **`client`** object: your connection to OpenAI that every later cell uses to send prompts.
#
# If you see `connected`, you are ready. If it fails, add your key in the Colab **Secrets** panel (the key icon on the left), then run the cell again.
#
# **Running in Jupyter or JupyterHub instead of Colab?** There are no Colab Secrets there, so do either:
# - Just run the setup cell and paste your key when it prompts (the input is hidden and not saved), or
# - Set it first: in a terminal run `export OPENAI_API_KEY=sk-...`, or in a cell run `import os; os.environ["OPENAI_API_KEY"] = "sk-..."`.

# %%
# === API check: confirm the connection and show the model(s) this lab uses ===
client = setup_openai()        # loads OPENAI_API_KEY + verifies it works

pp({
    "OpenAI":      "connected",
    "chat model":  DEFAULT_CHAT_MODEL,
    "mini model":  DEFAULT_MINI_MODEL,
}, title="API check")
# Out:
# OpenAI ready  |  model: gpt-5.4-mini  |  status: connected
#     <div style="background:#f8f9fb; border:1px solid #dde3ec; padding:12px 16px;
#                 border-radius:8px; margin:8px 0; font-family:monospace; font-size:13px;
#                 max-width:720px;">
#         <div style="font-size:12px; font-weight:700; color:#0055d4; margin-bottom:6px;">API check</div>
#         <pre style="margin:0; white-space:pre-wrap; color:#1a1a2e;">{
#   "OpenAI": "connected",
#   "chat model": "gpt-5.4",
#   "mini model": "gpt-5.4-mini"
# }</pre>
#     </div>

# %% [markdown]
# # Applied Generative AI
# Instructor: Prof. Dehghani
# Welcome to the Applied Generative AI course. In this course, we will explore the foundations and applications of Generative AI using tools like OpenAI's API. By the end of this session, you will:
#
# 🟢 Understand how to set up and connect to OpenAI's API.
# 🌟 Learn about the roles (System, Assistant, User) in prompt design.
# ✨ Generate text, images, and vector embeddings programmatically.
# 🔧 Explore fine-tuning to customize AI models for specific tasks.
# Let’s get started with setting up the OpenAI API!

# %%
# ==========================================================
# 1. Install the OpenAI Python SDK
# ==========================================================
# The modern OpenAI SDK (1.x+) gives us the `OpenAI` client used below for
# text, images, and embeddings. The shared setup cell already installs it, so
# this line just makes sure it is present when the lab runs on its own.
# !pip install -q --upgrade openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.0 MB/s eta 0:00:00

# %%
# ==========================================================
# 1. Confirm the API key is loaded
# ==========================================================
# The key was already loaded and validated by setup_openai() in the API-check
# cell above, so here we just confirm it is present in the environment.
# (For debugging only -- never print your real key in a shared notebook.)
print("Key loaded:", "Yes" if os.environ.get("OPENAI_API_KEY") else "No")
# Out:
# Key loaded: No

# %% [markdown]
# ## 📡 How Calling the API Actually Works
#
# Every time you ask the model a question, your notebook sends a **request** over the internet to OpenAI's servers and gets a **response** back. Think of it like texting a very fast assistant: you send a message, it replies. Here is the anatomy of that call, which you will see in the very next section:
#
# ```python
# response = client.chat.completions.create(
#     model=DEFAULT_MINI_MODEL,         # which model answers
#     messages=[                         # the conversation you send
#         {"role": "system", "content": "You are a helpful assistant."},
#         {"role": "user",  "content": "What is the capital of France?"}
#     ]
# )
# ```
#
# The pieces:
#
# - **`client`** is your connection to OpenAI, created earlier by `setup_openai()`. It already knows your API key.
# - **`client.chat.completions.create(...)`** is the request actually being sent.
# - **`model=`** chooses which model answers. Here it is the fast, low cost `DEFAULT_MINI_MODEL`.
# - **`messages=`** is the conversation: a list of turns, where each turn has a **role** (system, user, or assistant) and its **content**. You will learn what each role does right below.
#
# What comes back is a `response` object, and the model's actual answer lives at:
#
# ```python
# response.choices[0].message.content
# ```
#
# That is why the labs finish a call with `pretty_print(response.choices[0].message.content)`: it pulls out the reply text and shows it in a clean box. That one request and response is a single API call, and it usually costs a small fraction of a cent.

# %% [markdown]
# ## 1. Prompt Playground: Understanding Roles
# In OpenAI's API, you interact with the model using roles, which define the flow of the conversation:
#
# ➡️ System: Sets the behavior and tone of the assistant (e.g., "You are a cheerful assistant.").
# ➡️ User: Represents the input or question from the user (e.g., "What is AI?").
# ➡️ Assistant: Automatically generated responses based on the system and user inputs.
# 💡 Why Roles Matter: Roles help control the assistant's personality and the quality of responses. For example:
#
# A system message like "You are a strict teacher" makes the assistant respond more formally.
# A system message like "You are a friendly chatbot" leads to casual responses.
# Let’s see how these roles work in the next cell!
#
# ## Example 1: Without Assistant Role

# %%
# ==========================================================
# 1. Example 1 -- system + user roles (no assistant turn)
# ==========================================================
# The 'client' object is already set up by setup_openai() in the API Check cell.


response = client.chat.completions.create(
    model=DEFAULT_MINI_MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"}
    ]
)

pretty_print(response.choices[0].message.content, title="🤖 Model Response")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">🤖 Model Response</strong><br>
#         <span style="font-size: 14px; color: #333;">The capital of France is **Paris**.</span>
#     </div>

# %% [markdown]
# ## 2. Example 2: With Assistant Role

# %%
# ==========================================================
# 2. Example 2 -- seeding a prior assistant turn
# ==========================================================
# The 'client' object is already set up by setup_openai() in the API Check cell.

# Demonstrating roles in OpenAI's API with the assistant role

# Define the conversation including a predefined assistant response
messages = [
    {"role": "system", "content": "You are a math tutor who explains problems step by step."}, # System role sets the behavior
    {"role": "user", "content": "Solve for x: 2x + 5 = 15"}, # User question
    {"role": "assistant", "content": "To solve for x: \n1. Subtract 5 from both sides: 2x = 10\n2. Divide both sides by 2: x = 5"}  # Predefined assistant response
]

# Send the conversation to the API
response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL, # Use the chosen model
    messages=messages  # Pass the conversation
)

# Print the assistant's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Solve:<br>\[<br>2x + 5 = 15<br>\]<br><br>Step 1: Subtract 5 from both sides.<br>\[<br>2x = 10<br>\]<br><br>Step 2: Divide both sides by 2.<br>\[<br>x = 5<br>\]<br><br>Answer:<br>\[<br>\boxed{x = 5}<br>\]</span>
#     </div>

# %% [markdown]
# > **Pause and think.** Compare Example 1 and Example 2. The *system* message sets the assistant's persona; the *user* message is the question; a seeded *assistant* message shows the model an example answer to imitate. Did adding that assistant turn change the style or format of the reply?

# %% [markdown]
# **Your notes** *(double-click to edit)*
#
# - What the system role changed:
# - What the seeded assistant turn changed:
# - One prompt idea to try next:

# %% [markdown]
# ## 3. 🧮 Hands-On: complete the roles

# %%
# ==========================================================
# 3. Hands-on -- fill in the role names, then uncomment the call
# ==========================================================
# The 'client' object is already set up by setup_openai() in the API Check cell.

# ++++ Hands-On: Complete the Roles ++++

# Define the conversation using the role structure
messages = [
    {"role": "system", "content": "You are a math tutor who explains concepts clearly and step by step."}, # Complete the system role
    {"role": "user", "content": "How do you calculate the arithmetic mean of a set of numbers?"}, # Complete the user role
    {"role": "assistant", "content": "To calculate the arithmetic mean:\n" }# Optional predefined assistant response
]

# Send the conversation to the API
response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL, # Use the chosen model
    messages=messages  # Pass the conversation
)

# Print the assistant's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
# ...

# %% [markdown]
# ## 4. Exercise 1: Simple Q&A with System + User Roles
# 👉 Task:
# Write a prompt that asks the assistant to behave like a science teacher, then ask it a science-related question.

# %%
# ==========================================================
# 4. Exercise 1 -- your own system + user prompt
# ==========================================================
# The 'client' object is already set up by setup_openai() in the API Check cell.

# 🧠 Define your own roles and prompt below
messages = [
    {"role": "system", "content": "You are a science teacher."}, # Example: 'science teacher', 'debate coach'
    {"role": "user", "content": "Explain how respiration works."} # Example: 'Explain how photosynthesis works.'
]

# 🧠 Call the OpenAI API with your customized prompt
response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL,
    messages=messages
)

# 🧠 Print the model's response
pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
# ...

# %% [markdown]
# ## 5. ✍️ Exercise 2: Give a prompt of your choice.
# 👉 Task:
# Now write your own custom prompt. Use any role, any question, be creative!

# %%
# ==========================================================
# 5. Exercise 2 -- a prompt of your own
# ==========================================================
# The 'client' object is already set up by setup_openai() in the API Check cell.

# Replace with your own prompt idea!
messages = [
    {"role": "system", "content": "You are a Kindergarten teacher."}, # Fill in your desired system role
    {"role": "user", "content": "Write a short poem on phonics."} # Fill in your desired user query
]

response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL,
    messages=messages
)

pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
#         <span style="font-size: 14px; color: #333;">Phonics helps us sound and read,  <br>Letter by letter, that’s what we need.  <br>B says /b/, and C says /c/,  <br>Words come alive for you and me!  <br><br>Blend the sounds and read with cheer,  <br>Little readers grow each year.  <br>With every word, we learn and play,  <br>Phonics helps us all the way!</span>
#     </div>

# %%
messages = [
    {"role": "system", "content": "You are a Professor on AI."}, # Fill in your desired system role
    {"role": "user", "content": "Explain the topic of LLMs with examples."} # Fill in your desired user query
]

response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL,
    messages=messages
)

pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
# ...

# %%
messages = [
    {"role": "system", "content": "You are a puzzle maker."}, # Fill in your desired system role
    {"role": "user", "content": "Can you make up 5 riddles that can be solved by 13 year old."} # Fill in your desired user query
]

response = client.chat.completions.create(
    model=DEFAULT_CHAT_MODEL,
    messages=messages
)

pretty_print(response.choices[0].message.content, title="Assistant's Response:")
# Out:
#     <div style="border-left: 5px solid #1e4b8f;
#                 padding: 12px 16px;
#                 background-color: #f0f6ff;
#                 border-radius: 6px;
#                 font-family: 'Segoe UI', sans-serif;
#                 line-height: 1.6;
#                 margin: 10px 0;
#                 max-width: 720px;">
#         <strong style="color: #1e4b8f; font-size: 16px;">Assistant's Response:</strong><br>
# ...
